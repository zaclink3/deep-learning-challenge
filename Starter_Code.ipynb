# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df_drop = application_df.drop(['EIN', 'NAME'], axis=1)

# %%
# Determine the number of unique values in each column.
application_df_drop.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df_drop['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
from numpy.lib.function_base import append
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
cutoff_value = 50
application_types_to_replace = []

for app_type, count in application_df_drop['APPLICATION_TYPE'].value_counts().items():
    if count < cutoff_value:
        application_types_to_replace.append(app_type)


# Replace in dataframe
for app in application_types_to_replace:
    application_df_drop['APPLICATION_TYPE'] = application_df_drop['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df_drop['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# T13         66
# Other       54
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_df = application_df_drop['CLASSIFICATION'].value_counts()

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_one = class_df[class_df >1]
class_one
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
cutoff_value = 1000
classifications_to_replace = []

for class_type, count in application_df_drop['CLASSIFICATION'].value_counts().items():
    if count < cutoff_value:
        classifications_to_replace.append(class_type)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df_drop['CLASSIFICATION'] = application_df_drop['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
application_df_drop.columns
# Out:
# Index(['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE',
#        'ORGANIZATION', 'STATUS', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS',
#        'ASK_AMT', 'IS_SUCCESSFUL'],
#       dtype='object')

# %%
# Convert categorical data to numeric with `pd.get_dummies`
categorical_columns = ['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE',
       'ORGANIZATION', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS']
app_df = pd.get_dummies(application_df_drop, columns=categorical_columns)

app_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T13  APPLICATION_TYPE_T19  \
# 0                         1                     0                     0
# ...

# %%
app_df.to_csv('data_to_tune.csv', index=False)

# %%
# Split our preprocessed data into our features and target arrays
y = app_df["IS_SUCCESSFUL"].values
X = app_df.drop(["IS_SUCCESSFUL"],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
# Out:
# <ipython-input-11-22b05400c923>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = app_df.drop(["IS_SUCCESSFUL"],1).values

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  8
hidden_nodes_layer2 = 5

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 8)                 368
#
#  dense_1 (Dense)             (None, 5)                 45
#
#  dense_2 (Dense)             (None, 1)                 6
#
# ...
# Total params: 419
# Trainable params: 419
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 7s 3ms/step - loss: 0.6116 - accuracy: 0.6873
# Epoch 2/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5660 - accuracy: 0.7247
# Epoch 3/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5604 - accuracy: 0.7261
# Epoch 4/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5576 - accuracy: 0.7279
# Epoch 5/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5554 - accuracy: 0.7310
# Epoch 6/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5542 - accuracy: 0.7309
# Epoch 7/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5532 - accuracy: 0.7322
# Epoch 8/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5528 - accuracy: 0.7315
# Epoch 9/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5521 - accuracy: 0.7317
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5529 - accuracy: 0.7264 - 479ms/epoch - 2ms/step
# Loss: 0.5528874397277832, Accuracy: 0.7264139652252197

# %%
# Export our model to HDF5 file
nn.save('AlphabetSoupCharity.h5')

# %% [markdown]
# Optimizing the Model

# %%
# Create a method that creates a new Sequential model with hyperparameter options
def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh', 'ELU'])
    
    # Allow kerastuner to decide number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=30,
        step=5), activation=activation, input_dim=45))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 5)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=30,
            step=5),
            activation=activation))
    
    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])
    
    return nn_model

# %%
# !pip install keras_tuner
# Import the kerastuner library
import keras_tuner as kt

tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=10,
    hyperband_iterations=2)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.1/176.1 kB 3.9 MB/s eta 0:00:00
# ...

# %%
# Run the kerastuner search for best hyperparameters
# tuner.search(X_train_scaled, y_train, epochs=20, validation_data=(X_test_scaled, y_test), max_trails=10)

# tuner.search(X_train_scaled, y_train, epochs=20, validation_data=(X_test_scaled, y_test), max_trials=10)

# try:
tuner.search(X_train_scaled, y_train, epochs=10, validation_data=(X_test_scaled, y_test))
# except RuntimeError as e:
#     print(str(e))
# Out:
# Trial 60 Complete [00h 00m 42s]
# val_accuracy: 0.7267638444900513
#
# Best val_accuracy So Far: 0.7271137237548828
# Total elapsed time: 00h 16m 46s

# %%
# Get top 3 model hyperparameters and print the values
top_hyper = tuner.get_best_hyperparameters(3)
for param in top_hyper:
    print(param.values)
# Out:
# {'activation': 'tanh', 'first_units': 26, 'num_layers': 1, 'units_0': 16, 'units_1': 16, 'units_2': 16, 'units_3': 16, 'units_4': 21, 'tuner/epochs': 10, 'tuner/initial_epoch': 4, 'tuner/bracket': 2, 'tuner/round': 2, 'tuner/trial_id': '0043'}
# {'activation': 'relu', 'first_units': 16, 'num_layers': 5, 'units_0': 11, 'units_1': 21, 'units_2': 1, 'units_3': 21, 'units_4': 26, 'tuner/epochs': 10, 'tuner/initial_epoch': 4, 'tuner/bracket': 1, 'tuner/round': 1, 'tuner/trial_id': '0048'}
# {'activation': 'ELU', 'first_units': 21, 'num_layers': 5, 'units_0': 6, 'units_1': 11, 'units_2': 11, 'units_3': 21, 'units_4': 6, 'tuner/epochs': 4, 'tuner/initial_epoch': 2, 'tuner/bracket': 2, 'tuner/round': 1, 'tuner/trial_id': '0001'}

# %%
# Evaluate the top 3 models against the test dataset
top_model = tuner.get_best_models(3)
for model in top_model:
    model_loss, model_accuracy = model.evaluate(X_test_scaled,y_test,verbose=2)
    print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5536 - accuracy: 0.7271 - 577ms/epoch - 2ms/step
# Loss: 0.5536239147186279, Accuracy: 0.7271137237548828
# 268/268 - 1s - loss: 0.5577 - accuracy: 0.7270 - 655ms/epoch - 2ms/step
# Loss: 0.5576609969139099, Accuracy: 0.7269970774650574
# 268/268 - 1s - loss: 0.5564 - accuracy: 0.7269 - 672ms/epoch - 3ms/step
# Loss: 0.5563830137252808, Accuracy: 0.7268804907798767

# %%
#try only tanh to see if we can get a higher score

# Create a method that creates a new Sequential model with hyperparameter options
def create_model(hpt):
    tanh_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hpt.Choice('activation',['tanh'])
    
    # Allow kerastuner to decide number of neurons in first layer
    tanh_model.add(tf.keras.layers.Dense(units=hpt.Int('first_units',
        min_value=1,
        max_value=10,
        step=2), activation=activation, input_dim=45))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hpt.Int('num_layers', 1, 5)):
        tanh_model.add(tf.keras.layers.Dense(units=hpt.Int('units_' + str(i),
            min_value=1,
            max_value=10,
            step=2),
            activation=activation))
    
    tanh_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    tanh_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])
    
    return tanh_model

# %%
# !pip install keras_tuner
import keras_tuner as kt

tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=10,
    hyperband_iterations=2)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.1/176.1 kB 7.1 MB/s eta 0:00:00
# ...

# %%
tuner.search(X_train_scaled, y_train, epochs=10, validation_data=(X_test_scaled, y_test))
# Out:
# Trial 60 Complete [00h 00m 22s]
# val_accuracy: 0.7258309125900269
#
# Best val_accuracy So Far: 0.7269970774650574
# Total elapsed time: 00h 13m 40s

# %%
# Evaluate the top 3 models against the test dataset
top_model = tuner.get_best_models(3)
for model in top_model:
    model_loss, model_accuracy = model.evaluate(X_test_scaled,y_test,verbose=2)
    print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5549 - accuracy: 0.7270 - 896ms/epoch - 3ms/step
# Loss: 0.5549234747886658, Accuracy: 0.7269970774650574
# 268/268 - 1s - loss: 0.5603 - accuracy: 0.7268 - 1s/epoch - 4ms/step
# Loss: 0.5603057742118835, Accuracy: 0.7267638444900513
# 268/268 - 1s - loss: 0.5604 - accuracy: 0.7265 - 889ms/epoch - 3ms/step
# Loss: 0.5604445934295654, Accuracy: 0.7265306115150452
